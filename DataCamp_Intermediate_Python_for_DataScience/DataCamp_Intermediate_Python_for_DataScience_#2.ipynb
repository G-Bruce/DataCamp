# %% [markdown]
# # Intermediate Python for Data Science

# %% [markdown]
# ## Basic plots with matplotlib

# %%
year = range(1950, 2100)
pop = [2.53, 2.57, 2.62, 2.67, 2.71, 2.76, 2.81, 2.86, 2.92, 2.97, 3.03, 3.08, 3.14, 3.2, 3.26, 3.33, 3.4, 3.47, 3.54, 3.62, 3.69,
 3.77, 3.84, 3.92, 4.0, 4.07, 4.15, 4.22, 4.3, 4.37, 4.45, 4.53, 4.61, 4.69, 4.78, 4.86, 4.95, 5.05, 5.14, 5.23, 5.32, 5.41, 5.49,
 5.58, 5.66, 5.74, 5.82, 5.9, 5.98, 6.05, 6.13, 6.2, 6.28, 6.36, 6.44, 6.51, 6.59, 6.67, 6.75, 6.83, 6.92, 7.0, 7.08, 7.16, 
7.24, 7.32, 7.4, 7.48, 7.56, 7.64, 7.72, 7.79, 7.87, 7.94, 8.01, 8.08, 8.15, 8.22, 8.29, 8.36, 8.42, 8.49, 8.56, 8.62, 8.68, 
8.74, 8.8, 8.86, 8.92, 8.98, 9.04, 9.09, 9.15, 9.2, 9.26, 9.31, 9.36, 9.41, 9.46, 9.5, 9.55, 9.6, 9.64, 9.68, 9.73, 9.77, 9.81, 
9.85, 9.88, 9.92, 9.96, 9.99, 10.03, 10.06, 10.09, 10.13, 10.16, 10.19, 10.22, 10.25, 10.28, 10.31, 10.33, 10.36, 10.38, 10.41, 
10.43, 10.46, 10.48, 10.5, 10.52, 10.55, 10.57, 10.59, 10.61, 10.63, 10.65, 10.66, 10.68,
 10.7, 10.72, 10.73, 10.75, 10.77, 10.78, 10.79, 10.81, 10.82, 10.83, 10.84]

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Make a line plot: year on the x-axis, pop on the y-axis
plt.plot(year,pop)

# Display the plot with plt.show()
plt.show()

# %%
gdp_cap = [974.5803384, 5937.029525999998, 6223.367465, 4797.231267, 12779.37964, 34435.367439999995, 36126.4927, 29796.04834,
 1391.253792, 33692.60508, 1441.284873, 3822.137084, 7446.298803, 12569.85177, 9065.800825, 10680.79282,
 1217.032994, 430.0706916, 1713.778686, 2042.09524, 36319.23501, 706.016537, 1704.063724, 13171.63885,
 4959.114854, 7006.580419, 986.1478792, 277.5518587, 3632.557798, 9645.06142, 1544.750112, 14619.222719999998,
 8948.102923, 22833.30851, 35278.41874, 2082.4815670000007, 6025.3747520000015, 6873.262326000001, 5581.180998, 5728.353514,
 12154.08975, 641.3695236000002, 690.8055759, 33207.0844, 30470.0167, 13206.48452, 752.7497265, 32170.37442,
 1327.60891, 27538.41188, 5186.050003, 942.6542111, 579.2317429999998, 1201.637154, 3548.3308460000007, 39724.97867,
 18008.94444, 36180.78919, 2452.210407, 3540.651564, 11605.71449, 4471.061906, 40675.99635, 25523.2771,
 28569.7197, 7320.8802620000015, 31656.06806, 4519.461171, 1463.249282, 1593.06548, 23348.139730000006, 47306.98978,
 10461.05868, 1569.331442, 414.5073415, 12057.49928, 1044.770126, 759.3499101, 12451.6558, 1042.581557,
 1803.151496, 10956.99112, 11977.57496, 3095.7722710000007, 9253.896111, 3820.17523, 823.6856205, 944.0,
 4811.060429, 1091.359778, 36797.93332, 25185.00911, 2749.320965, 619.6768923999998, 2013.977305, 49357.19017,
 22316.19287, 2605.94758, 9809.185636, 4172.838464, 7408.905561, 3190.481016, 15389.924680000002, 20509.64777,
 19328.70901, 7670.122558, 10808.47561, 863.0884639000002, 1598.435089, 21654.83194, 1712.472136, 9786.534714,
 862.5407561000002, 47143.17964, 18678.31435, 25768.25759, 926.1410683, 9269.657808, 28821.0637, 3970.095407,
 2602.394995, 4513.480643, 33859.74835, 37506.41907, 4184.548089, 28718.27684, 1107.482182, 7458.396326999998,
 882.9699437999999, 18008.50924, 7092.923025, 8458.276384, 1056.380121, 33203.26128, 42951.65309, 10611.46299,
 11415.80569, 2441.576404, 3025.349798, 2280.769906, 1271.211593, 469.70929810000007]
print("The number of elements in the gdp_cap object is: " + str(len(gdp_cap)))
life_exp = [43.828, 76.423, 72.301, 42.731, 75.32, 81.235, 79.829, 75.635, 64.062, 79.441, 56.728, 65.554, 74.852, 50.728, 72.39, 73.005,
 52.295, 49.58, 59.723, 50.43, 80.653, 44.74100000000001, 50.651, 78.553, 72.961, 72.889, 65.152, 46.462, 55.322, 78.782, 48.328, 75.748,
 78.273, 76.486, 78.332, 54.791, 72.235, 74.994, 71.33800000000002, 71.878, 51.57899999999999, 58.04, 52.947, 79.313, 80.657, 56.735, 59.448, 79.406,
 60.022, 79.483, 70.259, 56.007, 46.38800000000001, 60.916, 70.19800000000001, 82.208, 73.33800000000002, 81.757, 64.69800000000001, 70.65, 70.964, 59.545, 78.885, 80.745,
 80.546, 72.567, 82.603, 72.535, 54.11, 67.297, 78.623, 77.58800000000002, 71.993, 42.592, 45.678, 73.952, 59.44300000000001, 48.303, 74.241, 54.467, 64.164, 72.801,
 76.195, 66.803, 74.543, 71.164, 42.082, 62.069, 52.90600000000001, 63.785, 79.762, 80.204, 72.899, 56.867, 46.859, 80.196, 75.64, 65.483,
 75.53699999999998, 71.752, 71.421, 71.688, 75.563, 78.098, 78.74600000000002, 76.442, 72.476, 46.242, 65.528, 72.777, 63.062, 74.002, 42.56800000000001, 79.972,
 74.663, 77.926, 48.159, 49.339, 80.941, 72.396, 58.556, 39.613, 80.884, 81.70100000000002, 74.143, 78.4, 52.517, 70.616, 58.42, 69.819,
 73.923, 71.777, 51.542, 79.425, 78.242, 76.384, 73.747, 74.249, 73.422, 62.698, 42.38399999999999, 43.487]
print("The number of elements in the life_exp object is: " + str(len(life_exp)))

print("The number of elements within life_exp is equal to the number of elementes within gdp_cap: " + str(len(life_exp) == len(gdp_cap)))

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Make a line plot, gdp_cap on the x-axis, life_exp on the y-axis

plt.plot(gdp_cap, life_exp)

# Display the plot
plt.show()

# Change the line plot below to a scatter plot
plt.scatter(gdp_cap, life_exp)

# Put the x-axis on a logarithmic scale
plt.xscale('log')

# Show plot
plt.show()

# Build Scatter plot
#plt.scatter(pop, life_exp)

# Show plot
#plt.show()

# Create histogram of life_exp data
plt.hist(life_exp)

# Display histogram
plt.show()

# Build histogram with 5 bins
plt.hist(life_exp,bins=5)

# Show and clean up plot
plt.show()
plt.clf()

# Build histogram with 20 bins
plt.hist(life_exp,bins=20)

# Show and clean up again
plt.show()
plt.clf()

# Histogram of life_exp, 15 bins
plt.hist(life_exp,bins=15)

# Show and clear plot
plt.show()
plt.clf()
# Out:
# The number of elements in the gdp_cap object is: 142
# The number of elements in the life_exp object is: 142
# The number of elements within life_exp is equal to the number of elementes within gdp_cap: True

# %% [markdown]
# ## Labels

# %%
# Basic scatter plot, log scale
plt.scatter(gdp_cap, life_exp)
plt.xscale('log') 

# Strings
xlab = 'GDP per Capita [in USD]'
ylab = 'Life Expectancy [in years]'
title = 'World Development in 2007'

# Add axis labels
plt.xlabel(xlab)
plt.ylabel(ylab)

# Add title
plt.title(title)

# After customizing, display the plot
plt.show()

# %% [markdown]
# # Ticks

# %%
# Scatter plot
plt.scatter(gdp_cap, life_exp)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')

# Definition of tick_val and tick_lab
tick_val = [1000,10000,100000]
tick_lab = ['1k','10k','100k']

# Adapt the ticks on the x-axis
plt.xticks(tick_val,tick_lab)

# After customizing, display the plot
plt.show()

# %% [markdown]
# ## Sizes

# %%
# Import numpy as np
import numpy as np

# Store pop as a numpy array: np_pop
np_pop = np.array(pop)

# Double np_pop
np_pop = np_pop * 2

# Update: set s argument to np_pop
plt.scatter(gdp_cap, life_exp, s = np_pop)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])

# Display the plot
plt.show()

# %% [markdown]
# ## Color

# %%
# Specify c and alpha inside plt.scatter()
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2, c = col, alpha=0.8)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Show the plot
plt.show()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-30-cedb1fe79729> in <module>()
#       1 # Specify c and alpha inside plt.scatter()
# ----> 2 plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2, c = col, alpha=0.8)
#       3
#       4 # Previous customizations
#       5 plt.xscale('log')
#
# NameError: name 'col' is not defined

# %% [markdown]
# ## Plot Callouts

# %%
# Scatter plot
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2, alpha = 0.8)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Additional customizations - Plot Callouts
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')

# Add grid() call
plt.grid(True)

# %% [markdown]
# # Dictionaries, Part 1

# %% [markdown]
# ## List using Index

# %%
pop = [30.55, 2.77, 39.21]
countries = ["afghanistan", "albania", "algeria"]

idx_albania = countries.index("albania")

print("The albania index is: " + str(idx_albania))

print("The albania population is: " + str(pop[idx_albania]) + " million people.")
# Out:
# The albania index is: 1
# The albania population is: 2.77 million people.

# %% [markdown]
# ## Using a Dictionary

# %%
world = {"afghanistan":30.55, "albania":2.77, "algeria":39.21}
print("The albania population is: " + str(world["albania"]) + " million people.")
# Out:
# The albania population is: 2.77 million people.

# %% [markdown]
# ## Create Dictionary

# %%
# Definition of countries and capital
countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

print("Countries is of type: " + str(type(countries)))

# From string in countries and capitals, create dictionary europe
europe = dict(zip(countries, capitals))

# Print europe
print(europe)

# Print out the keys in europe
print("The keys that are in europe are: " + str(europe.keys()))

# Print out value that belongs to key 'norway'
print("The value that belongs to key 'norway' is: " + str(europe['norway']))

# Keys in a distionary:
#   1) "should" be unique, if they are not, the last key and value pair is maintained
#   2) Keys are immutable
#   3) Lists are not allowed as a Key

# Add a new key-value to europe
europe["sealand"] = 0.000028

# Print europe
print(europe)

# Modify existing value of sealand
europe["sealand"] = "micro-capital"

# Print europe
print(europe)

# Remove sealand from the europe dictinary
del(europe["sealand"])

# Print europe
print(europe)
# Out:
# Countries is of type: <type 'list'>
# {'norway': 'oslo', 'germany': 'berlin', 'spain': 'madrid', 'france': 'paris'}
# The keys that are in europe are: ['norway', 'germany', 'spain', 'france']
# The value that belongs to key 'norway' is: oslo
# {'sealand': 2.8e-05, 'norway': 'oslo', 'germany': 'berlin', 'spain': 'madrid', 'france': 'paris'}
# {'sealand': 'micro-capital', 'norway': 'oslo', 'germany': 'berlin', 'spain': 'madrid', 'france': 'paris'}
# {'norway': 'oslo', 'germany': 'berlin', 'spain': 'madrid', 'france': 'paris'}

# %% [markdown]
# ## Dictionary Manipulation

# %%
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# Add italy to europe
europe["italy"] = 'rome'

# Print out italy in europe
print('italy' in europe)

# Add poland to europe
europe["poland"] = 'warsaw'

# Print europe
print(europe)

# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'bonn',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw',
          'australia':'vienna' }

# Print europe
print(europe)

# Update capital of germany
europe['germany']='berlin'

# Print europe
print(europe)

# Remove australia
del(europe['australia'])

# Print europe
print(europe)
# Out:
# True
# {'italy': 'rome', 'poland': 'warsaw', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'spain': 'madrid'}
# {'australia': 'vienna', 'italy': 'rome', 'poland': 'warsaw', 'france': 'paris', 'germany': 'bonn', 'norway': 'oslo', 'spain': 'madrid'}
# {'australia': 'vienna', 'italy': 'rome', 'poland': 'warsaw', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'spain': 'madrid'}
# {'italy': 'rome', 'poland': 'warsaw', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'spain': 'madrid'}

# %% [markdown]
# ## Dictionariception

# %%
# Dictionary of dictionaries
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }


# Print out the capital of France
print("the capital of France is: " + str(europe['france']['capital']))

# Create sub-dictionary data
data = {'capital': 'rome', 'population': 59.83}

# Add data to europe under key 'italy'
europe['italy']=data

# Print europe
print(europe)
# Out:
# paris
# {'norway': {'population': 5.084, 'capital': 'oslo'}, 'italy': {'population': 59.83, 'capital': 'rome'}, 'germany': {'population': 80.62, 'capital': 'berlin'}, 'spain': {'population': 46.77, 'capital': 'madrid'}, 'france': {'population': 66.03, 'capital': 'paris'}}

# %% [markdown]
# ## Pandas, Part 1

# %% [markdown]
# ### Dictionary to DataFrame

# %%
# Pre-defined lists
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# Import pandas as pd
import pandas as pd

# Create dictionary my_dict with three key:value pairs: my_dict
my_dict = {'country':names,'drives_right':dr,'cars_per_cap':cpc}

# Build a DataFrame cars from my_dict: cars
cars = pd.DataFrame(my_dict)

# Print cars
print(cars)


# Build cars DataFrame
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
dict = { 'country':names, 'drives_right':dr, 'cars_per_cap':cpc }
cars = pd.DataFrame(dict)

print(cars)

# Definition of row_labels
row_labels = ['US', 'AUS', 'JAP', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index = (row_labels)

# Print cars again
print(cars)
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70        Morocco          True
# 6            45          Egypt          True
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70        Morocco          True
# 6            45          Egypt          True
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# ...

# %% [markdown]
# ## Dictionary to DataFrame (1)

# %%
# Pre-defined lists
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# Import pandas as pd
import pandas as pd

# Create dictionary my_dict with three key:value pairs: my_dict
my_dict = {'country':names,'drives_right':dr,'cars_per_cap':cpc}

# Build a DataFrame cars from my_dict: cars
cars = pd.DataFrame(my_dict)

# Print cars
print(cars)
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70        Morocco          True
# 6            45          Egypt          True

# %% [markdown]
# ## Dictionary to DataFrame (2)

# %%
import pandas as pd

# Build cars DataFrame
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]
dict = { 'country':names, 'drives_right':dr, 'cars_per_cap':cpc }
cars = pd.DataFrame(dict)
print(cars)

# Definition of row_labels
row_labels = ['US', 'AUS', 'JAP', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index = (row_labels)

# Print cars again
print(cars)
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70        Morocco          True
# 6            45          Egypt          True
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %% [markdown]
# ### CSV to DataFrame

# %%
# Import pandas as pd
import pandas as pd

# Fix import by including index_col
cars = pd.read_csv('/Users/bgranger/Documents/SMU/6372_Applied Statistics/Unit_1/Titantic/submission_csv.csv')

# Print out cars
print(cars)

# Fix import by including index_col
cars = pd.read_csv('/Users/bgranger/Documents/SMU/6372_Applied Statistics/Unit_1/Titantic/submission_csv.csv', index_col = 0)

# Print out cars
print(cars)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         0
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         1
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         1
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         1
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...

# %% [markdown]
# ## Square Brackets (1)

# %%
# Import cars data
import pandas as pd
path_file = '/Users/bgranger/cars.csv'
cars = pd.read_csv(path_file, index_col = 0)

print(cars)

# Print out country column as Pandas Series
print(cars['country'])

# Print out country column as Pandas DataFrame
print(cars[['country']])

# Print out DataFrame with country and drives_right columns
print(cars[['country','drives_right']])
# Out:
#      cars_per_cap      country    drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True
# KeyErrorTraceback (most recent call last)
# <ipython-input-11-b20db0150af2> in <module>()
#       7
#       8 # Print out country column as Pandas Series
# ----> 9 print(cars['country'])
#      10
#      11 # Print out country column as Pandas DataFrame
#
# C:\Users\bgranger\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ...

# %% [markdown]
# ## Square Brackets (2)

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Print out first 3 observations
print(cars[0:3])

# Print out fourth, fifth and sixth observation
print(cars[3:6])
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
#      cars_per_cap  country  drives_right
# IN             18    India         False
# RU            200   Russia          True
# MOR            70  Morocco          True

# %% [markdown]
# ## loc and iloc (1)

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Print cars
print(cars);print("")

# Print out observation for Japan
print(cars.loc['JAP'])
print("")

# Print out observations for Australia and Egypt
print(cars.loc[['AUS', 'EG']])
print("")

# Print out drives_right value of Morocco
print("The drives_right value of Morocco is: " + str(cars.loc['MOR', 'drives_right']))
print("")

# Print sub-DataFrame
print(cars.loc[['RU', 'MOR'], ['country', 'drives_right']])
print("")

# Print out drives_right column as Series
print("Print out drives_right column as Series:")
print(cars.loc[:, 'drives_right'])
print("")

# Print out drives_right column as DataFrame
print("Print out drives_right column as DataFrame:")
print(cars.loc[:, ['drives_right']])
print("")

# Print out cars_per_cap and drives_right as DataFrame
print("Print out cars_per_cap and drives_right as DataFrame:")
print(cars.iloc[:, [0,2]])
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True
#
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JAP, dtype: object
#
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False
# EG             45      Egypt          True
#
# The drives_right value of Morocco is: True
#
#      country  drives_right
# RU    Russia          True
# MOR  Morocco          True
#
# Print out drives_right column as Series:
# US      True
# AUS    False
# JAP    False
# IN     False
# RU      True
# MOR     True
# EG      True
# Name: drives_right, dtype: bool
#
# Print out drives_right column as DataFrame:
# ...

# %% [markdown]
# # Logic, Control Flow and Filtering

# %% [markdown]
# ## Equality

# %%
# Comparison of booleans
print("True == False: " + str(True == False))

# Comparison of integers
print("-5 * 15 != 75: " + str(-5 * 15 != 75))

# Comparison of strings
print("pyscript == PyScript: " + str("pyscript" == "PyScript"))

# Compare a boolean with an integer
print("True == 1: " + str(True == 1))
# Out:
# True == False: False
# -5 * 15 != 75: True
# pyscript == PyScript: False
# True == 1: True

# %% [markdown]
# ## Compare arrays

# %%
# Create arrays
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# my_house greater than or equal to 18

print(my_house >= 18)

# my_house less than your_house
print(my_house < your_house)
# Out:
# [ True  True False False]
# [False  True  True False]

# %% [markdown]
# ## and, or, not

# %%
# Define variables
my_kitchen = 18.0
your_kitchen = 14.0

# my_kitchen bigger than 10 and smaller than 18?
print(my_kitchen > 10 and my_kitchen < 18)

# my_kitchen smaller than 14 or bigger than 17?
print(my_kitchen < 14 or my_kitchen > 17)

# Double my_kitchen smaller than triple your_kitchen?
print(my_kitchen *2 < 14 or your_kitchen * 3 > 17)
# Out:
# False
# True
# True

# %% [markdown]
# ## Boolean operators with Numpy

# %%
# Create arrays
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# my_house greater than 18.5 or smaller than 10
print(np.logical_or(my_house > 18.5, my_house < 10))

# Both my_house and your_house smaller than 11
print(np.logical_and(my_house < 11, your_house < 11))
# Out:
# [False  True False  True]
# [False False False  True]

# %% [markdown]
# ## if, elif, else

# %%
# Define variables
room = "kit"
area = 14.0

# if statement for room
if room == "kit" :
    print("Looking around in the kitchen.")

# if statement for area
if area > 15 :
    print("big place!")
# Out:
# Looking around in the kitchen.

# %%
# Define variables
room = "kit"
area = 14.0

# if-else construct for room
if room == "kit" :
    print("Looking around in the kitchen.")
else :
    print("Looking around elsewhere.")

# if-else construct for area
if area > 15:
    print("Big place!")
else:
    print("Pretty small.")
# Out:
# Looking around in the kitchen.
# Pretty small.

# %%
# Define variables
room = "bed"
area = 14.0

# if-elif-else construct for room
if room == "kit" :
    print("Looking around in the kitchen.")
elif room == "bed":
    print("Looking around in the bedroom.")
else :
    print("Looking around elsewhere.")

# if-elif-else construct for area
if area > 15 :
    print("Big place!")
elif area > 10:
    print("Medium size, nice!")
else :
    print("Pretty small.")
# Out:
# Looking around in the bedroom.
# Medium size, nice!

# %% [markdown]
# ## Filtering Pandas DataFrame

# %% [markdown]
# ## Driving right

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Extract drives_right column as Series: dr
dr = cars['drives_right']  # Pandas Series

# Use dr to subset cars: sel
sel = cars[dr]

# Print sel
print(sel)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
# Convert code to a one-liner
dr = cars['drives_right'] # Pandas Series
sel = cars[cars['drives_right']]

# Print dr
print(dr)

print("")

# Print sel
print(sel)
# Out:
# US      True
# AUS    False
# JAP    False
# IN     False
# RU      True
# MOR     True
# EG      True
# Name: drives_right, dtype: bool
#
#      cars_per_cap        country  drives_right
# US            809  United States          True
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Create car_maniac: observations that have a cars_per_cap over 500
cpc = cars['cars_per_cap'] # Pandas Series

# Print cpc
print(cpc);print("")

# Filter cpc for countries greater than 500:
cpc_gtrThan500 = cpc > 500

# Join cp_gtrThan500 with the orginal dataset
car_maniac = cars[cpc_gtrThan500] 

# Print car_maniac
print(car_maniac)
# Out:
# US     809
# AUS    731
# JAP    588
# IN      18
# RU     200
# MOR     70
# EG      45
# Name: cars_per_cap, dtype: int64
#
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False

# %% [markdown]
# ## Cars per capita

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Import numpy, you'll need this
import numpy as np

# Create medium: observations with cars_per_cap between 100 and 500
cpc = cars['cars_per_cap'] # Pandas Series
between = np.logical_and(cpc > 100, cpc < 500)
medium = cars[between]

# Print medium
print(medium)
# Out:
#     cars_per_cap country  drives_right
# RU           200  Russia          True

# %% [markdown]
# ## While Loop

# %%
# Initialize offset
offset = 8

# Code the while loop
while offset != 0:
    print('correcting...')
    offset = offset - 1
    print(offset)
# Out:
# correcting...
# 7
# correcting...
# 6
# correcting...
# 5
# correcting...
# 4
# correcting...
# 3
# correcting...
# 2
# correcting...
# 1
# correcting...
# 0

# %% [markdown]
# ## While with conditionals

# %%
# Initialize offset
offset = -6

# Code the while loop
while offset != 0 :
    print("correcting...")
    if offset > 0:
        offset = offset -1
        print(offset)
    else:
        offset = offset + 1
        
        if offset == 0:
            print(" " + str(offset))
        else:
            print(offset)
# Out:
# correcting...
# -5
# correcting...
# -4
# correcting...
# -3
# correcting...
# -2
# correcting...
# -1
# correcting...
#  0

# %% [markdown]
# ## For Loop - Loop Over a List

# %%
# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Code the for loop
for area in areas:
    print(area)
# Out:
# 9.5
# 9.5
# 9.5
# 9.5
# 9.5

# %% [markdown]
# ## For Loop - Indexes and values

# %%
# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Code the for loop
for index, area in enumerate(areas) :
    print("Room " + str(index + 1) + ": " + str(area)) #Base Zero Indexing
# Out:
# Room 1: 11.25
# Room 2: 18.0
# Room 3: 20.0
# Room 4: 10.75
# Room 5: 9.5

# %% [markdown]
# ## Loop over list of lists

# %%
# house list of lists
house = [["hallway", 11.25], 
         ["kitchen", 18.0], 
         ["living room", 20.0], 
         ["bedroom", 10.75], 
         ["bathroom", 9.50]]

# Print house
print(house);print("")
         
# Build a for loop from scratch
# As you iterate through the sublist, at the exact same positions

for x in house:
    print("The " + x[0] + " is " + str(x[1]) + " sqm")
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0], ['bedroom', 10.75], ['bathroom', 9.5]]
#
# The hallway is 11.25 sqm
# The kitchen is 18.0 sqm
# The living room is 20.0 sqm
# The bedroom is 10.75 sqm
# The bathroom is 9.5 sqm

# %% [markdown]
# ## Loop over dictionary

# %%
# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'bonn', 
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw', 'australia':'vienna' }
          
# Iterate over europe
for x, y in europe.items():
    print("The capital of " + x.title() + " is " + y.title() + ".")
# Out:
# The capital of Australia is Vienna.
# The capital of Italy is Rome.
# The capital of Poland is Warsaw.
# The capital of France is Paris.
# The capital of Germany is Bonn.
# The capital of Norway is Oslo.
# The capital of Spain is Madrid.

# %% [markdown]
# ## Loop over Numpy array

# %%
# Import numpy as np
import numpy as np

np_height = np.array([74, 74, 72, 45, 33, 46, 78, 93, 45, 43, 89, 80, 29, 44, 67, 75, 75, 73])

# For loop over np_height
for x in np_height:
    print(str(x) + " inches")

np_baseball = np.array([[ 74, 180], [ 74, 215], [ 72, 210], [ 72, 210], [ 75, 205], [ 75, 190], [ 73, 195]])    
    
# For loop over np_baseball
for x in np.nditer(np_baseball):
    print(x)
# Out:
# 74 inches
# 74 inches
# 72 inches
# 45 inches
# 33 inches
# 46 inches
# 78 inches
# 93 inches
# 45 inches
# 43 inches
# 89 inches
# 80 inches
# 29 inches
# 44 inches
# 67 inches
# 75 inches
# 75 inches
# 73 inches
# 74
# 180
# 74
# 215
# 72
# 210
# 72
# 210
# 75
# 205
# 75
# 190
# 73
# 195

# %% [markdown]
# ## Loop over DataFrame

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Print the cars data
print(cars);print("")

# Iterate over rows of cars
for lab, row in cars.iterrows() :
    print(lab)
    print(row);print("")
    
# Adapt for loop
for lab, row in cars.iterrows() :
    print(lab + ": " + str(row['cars_per_cap']))
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True
#
# US
# cars_per_cap              809
# country         United States
# drives_right             True
# Name: US, dtype: object
#
# AUS
# cars_per_cap          731
# country         Australia
# drives_right        False
# Name: AUS, dtype: object
#
# JAP
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JAP, dtype: object
#
# IN
# cars_per_cap       18
# country         India
# drives_right    False
# Name: IN, dtype: object
#
# RU
# cars_per_cap       200
# country         Russia
# drives_right      True
# Name: RU, dtype: object
#
# MOR
# cars_per_cap         70
# ...

# %% [markdown]
# ## Add column

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Code for loop that adds COUNTRY column
for lab, row in cars.iterrows() :
    cars.loc[lab, 'COUNTRY'] = row['country'].upper()

# Print cars
print(cars);print("")

cars['Country_LEN'] = cars['country'].apply(len)

# Print cars
print(cars)
# Out:
#      cars_per_cap        country  drives_right        COUNTRY
# US            809  United States          True  UNITED STATES
# AUS           731      Australia         False      AUSTRALIA
# JAP           588          Japan         False          JAPAN
# IN             18          India         False          INDIA
# RU            200         Russia          True         RUSSIA
# MOR            70        Morocco          True        MOROCCO
# EG             45          Egypt          True          EGYPT
#
#      cars_per_cap        country  drives_right        COUNTRY  Country_LEN
# US            809  United States          True  UNITED STATES           13
# AUS           731      Australia         False      AUSTRALIA            9
# JAP           588          Japan         False          JAPAN            5
# IN             18          India         False          INDIA            5
# RU            200         Russia          True         RUSSIA            6
# ...

# %% [markdown]
# ## Add Column 2

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)

# Use .apply(str.upper)
cars['COUNTRY'] = cars['country'].apply(str.upper)
print(cars)
# Out:
#      cars_per_cap        country  drives_right        COUNTRY
# US            809  United States          True  UNITED STATES
# AUS           731      Australia         False      AUSTRALIA
# JAP           588          Japan         False          JAPAN
# IN             18          India         False          INDIA
# RU            200         Russia          True         RUSSIA
# MOR            70        Morocco          True        MOROCCO
# EG             45          Egypt          True          EGYPT

# %% [markdown]
# # Random Numbers

# %% [markdown]
# ## Random float

# %%
# Import numpy as np
import numpy as np

# Set the seed
np.random.seed(123)

# Generate and print random float
print("The random float value is: " + str(np.random.rand()))
# Out:
# The random float value is: 0.696469185598

# %% [markdown]
# ## Roll the dice

# %%
# Import numpy and set seed
import numpy as np
np.random.seed(123)

# Use randint() to simulate a dice
print("Use randint(1,7) to simulate a dice roll: " + str(np.random.randint(1,7)))

# Use randint() again
print("Use randint(1,7) to simulate a dice roll: " + str(np.random.randint(1,7)))
# Out:
# Use randint(1,7) to simulate a dice roll: 6
# Use randint(1,7) to simulate a dice roll: 3

# %% [markdown]
# ## Determine your next move

# %%
# Import numpy and set seed
import numpy as np
np.random.seed(123)

# Starting step
step = 50

# Roll the dice
dice = np.random.randint(1,7)

# Finish the control construct
if dice <= 2 :
    step = step - 1
elif dice <= 5 :
    step = step + 1
else :
    step = step + np.random.randint(1,7)

# Print out dice and step
print(dice)
print(step)
# Out:
# 6
# 53

# %% [markdown]
# # Random Walk

# %% [markdown]
# ## The next step

# %%
# Import numpy and set seed
import numpy as np
np.random.seed(123)

# Initialize random_walk
random_walk = [0]
# Complete the random_walk
for x in range(100) :
    # Set step: last element in random_walk
    step = random_walk[x]

    # Roll the dice
    dice = np.random.randint(1,7)

    # Determine next step
    if dice <= 2:
        step = step - 1
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    # append next_step to random_walk
    random_walk.append(step)

# Print random_walk
print(random_walk)
# Out:
# [0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, -1, 0, 5, 4, 3, 4, 3, 4, 5, 6, 7, 8, 7, 8, 7, 8, 9, 10, 11, 10, 14, 15, 14, 15, 14, 15, 16, 17, 18, 19, 20, 21, 24, 25, 26, 27, 32, 33, 37, 38, 37, 38, 39, 38, 39, 40, 42, 43, 44, 43, 42, 43, 44, 43, 42, 43, 44, 46, 45, 44, 45, 44, 45, 46, 47, 49, 48, 49, 50, 51, 52, 53, 52, 51, 52, 51, 52, 53, 52, 55, 56, 57, 58, 57, 58, 59]

# %% [markdown]
# ## How low can you go?

# %%
# Import numpy and set seed
import numpy as np
np.random.seed(123)

# Initialize random_walk
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        # Replace below: use max to make sure step can't go below 0
        step = max(0, step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

print(random_walk)
# Out:
# [0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, 0, 1, 6, 5, 4, 5, 4, 5, 6, 7, 8, 9, 8, 9, 8, 9, 10, 11, 12, 11, 15, 16, 15, 16, 15, 16, 17, 18, 19, 20, 21, 22, 25, 26, 27, 28, 33, 34, 38, 39, 38, 39, 40, 39, 40, 41, 43, 44, 45, 44, 43, 44, 45, 44, 43, 44, 45, 47, 46, 45, 46, 45, 46, 47, 48, 50, 49, 50, 51, 52, 53, 54, 53, 52, 53, 52, 53, 54, 53, 56, 57, 58, 59, 58, 59, 60]

# %% [markdown]
# ## Visualize the walk

# %%
# Initialization
import numpy as np
np.random.seed(123)
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        step = max(0, step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Plot random_walk
plt.plot(random_walk)

# Show the plot
plt.show()
plt.clf()

# %% [markdown]
# # Distribution

# %% [markdown]
# ## Simulate multiple walks

# %%
# Initialization
import numpy as np
np.random.seed(123)

# Initialize all_walks
all_walks = []

# Simulate random walk 10 times
for i in range(10) :

    # Code from before
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)

        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)

    # Append random_walk to all_walks
    all_walks.append(random_walk)

# Print all_walks
print(all_walks)
# Out:
# [[0, 3, 4, 5, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1, 0, 0, 1, 6, 5, 4, 5, 4, 5, 6, 7, 8, 9, 8, 9, 8, 9, 10, 11, 12, 11, 15, 16, 15, 16, 15, 16, 17, 18, 19, 20, 21, 22, 25, 26, 27, 28, 33, 34, 38, 39, 38, 39, 40, 39, 40, 41, 43, 44, 45, 44, 43, 44, 45, 44, 43, 44, 45, 47, 46, 45, 46, 45, 46, 47, 48, 50, 49, 50, 51, 52, 53, 54, 53, 52, 53, 52, 53, 54, 53, 56, 57, 58, 59, 58, 59, 60], [0, 4, 3, 2, 4, 3, 4, 6, 7, 8, 13, 12, 13, 14, 15, 16, 17, 16, 21, 22, 23, 24, 23, 22, 21, 20, 19, 20, 21, 22, 28, 27, 26, 25, 26, 27, 28, 27, 28, 29, 28, 33, 34, 33, 32, 31, 30, 31, 30, 29, 31, 32, 35, 36, 38, 39, 40, 41, 40, 39, 40, 41, 42, 43, 42, 43, 44, 45, 48, 49, 50, 49, 50, 49, 50, 51, 52, 56, 55, 54, 55, 56, 57, 56, 57, 56, 57, 59, 64, 63, 64, 65, 66, 67, 68, 69, 68, 69, 70, 71, 73], [0, 2, 1, 2, 3, 6, 5, 6, 5, 6, 7, 8, 7, 8, 7, 8, 9, 11, 10, 9, 10, 11, 10, 12, 13, 14, 15, 16, 17, 18, 17, 18, 19, 24, 25, 24, 23, 22, 21, 22, 23, 24, 29, 30, 29, 30, 31, 32, 33, 34, 35, 34, 33, 34, 33, 39, 38, 39, 38, 39, 38,
# ...

# %% [markdown]
# ## Visualize all walks

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(123)
all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)
    
# Convert all_walks to Numpy array: np_aw
np_aw = np.array(all_walks)

# Plot np_aw and show
plt.plot(np_aw)
plt.show()
# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()
plt.clf()

# %% [markdown]
# ## Implement clumsiness

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(123)
all_walks = []

# Simulate random walk 250 times
for i in range(250) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        # generate a random float between 0 and 1. If this value is less than or equal to 0.001, you should reset step to 0.
        if np.random.rand(0,2) <= 0.001 :
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()
plt.clf()
# Out:
# C:\Users\bgranger\Anaconda2\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.

# %% [markdown]
# ## Plot the distribution

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(123)
all_walks = []

# Simulate random walk 500 times
for i in range(5000) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))

# Select last row from np_aw_t: ends
ends = np.array(np_aw_t[-1])

# Plot histogram of ends, display plot
plt.hist(ends)
plt.show()

# %% [markdown]
# ## Calculate the odds

# %%
gtrEql60 = float()
for x in ends:
    if x >= 60:
        gtrEql60 = gtrEql60 + 1
print("The count of values that are greater than or equal to 60 is: " + str(gtrEql60))
print("")
perOfTotal = gtrEql60/5000
print("The percent of values that are greater than or equal to 60 is: " + str(gtrEql60/5000*100) + "%")
# Out:
# The count of values that are greater than or equal to 60 is: 3878.0
#
# The percent of values that are greater than or equal to 60 is: 77.56%
